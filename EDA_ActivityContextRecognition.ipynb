# %% [markdown]
# #**Exploratory Data Analysis**

# %%
#Importing the necessary libraries
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import plotly.express as px
pd.options.display.float_format = '{:.2f}'.format
import warnings
warnings.filterwarnings('ignore')

# %%
# reading CSV using Pandas and storing in dataframe       
df = pd.read_csv("newfile.csv")
display(df)
# Out:
#            _id  orX  orY  orZ    rX    rY    rZ  accX  accY  accZ    gX    gY  \
# 0            1  125  -17    2  0.07 -0.13 -0.88 -0.04  2.68  8.66 -0.04  2.68
# 1            2  126  -17    2  0.07 -0.13 -0.88 -0.04  2.68  8.66 -0.05  2.68
# 2            3  127  -17    2  0.07 -0.13 -0.88  0.15  2.68  8.66 -0.06  2.68
# 3            4  127  -17    2  0.07 -0.13 -0.88  0.15  2.68  8.66 -0.06  2.68
# 4            5  127  -17    2  0.07 -0.13 -0.88  0.15  2.68  8.66 -0.05  2.68
# ...        ...  ...  ...  ...   ...   ...   ...   ...   ...   ...   ...   ...
# 205515  205516  286    6   -2 -0.07 -0.04  0.62 -0.38 -0.80 10.61 -0.19 -1.69
# 205516  205517  286    6   -2 -0.07 -0.04  0.62 -0.38 -0.80 10.61 -0.19 -1.69
# 205517  205518  286    6   -2 -0.07 -0.04  0.62 -0.38 -0.80 10.61 -0.19 -1.69
# 205518  205519  288    4   -2 -0.07 -0.04  0.62 -0.38 -1.15 10.61 -0.20 -1.62
# 205519  205520  288    4   -2 -0.07 -0.04  0.62 -0.38 -1.15 10.61 -0.20 -1.62
#
# ...

# %%
#Data Info
df.shape
# Out:
# (205520, 19)

# %%
#Columns of the dataset
df.columns
# Out:
# Index(['_id', 'orX', 'orY', 'orZ', 'rX', 'rY', 'rZ', 'accX', 'accY', 'accZ',
#        'gX', 'gY', 'gZ', 'mX', 'mY', 'mZ', 'lux', 'soundLevel', 'activity'],
#       dtype='object')

# %%
#Information about the dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205520 entries, 0 to 205519
# Data columns (total 19 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   _id         205520 non-null  int64
#  1   orX         205520 non-null  int64
#  2   orY         205520 non-null  int64
#  3   orZ         205520 non-null  int64
#  4   rX          205520 non-null  float64
#  5   rY          205520 non-null  float64
#  6   rZ          205520 non-null  float64
#  7   accX        205520 non-null  float64
#  8   accY        205520 non-null  float64
#  9   accZ        205520 non-null  float64
#  10  gX          205520 non-null  float64
#  11  gY          205520 non-null  float64
#  12  gZ          205520 non-null  float64
#  13  mX          205520 non-null  float64
#  14  mY          205520 non-null  float64
#  15  mZ          205520 non-null  float64
#  16  lux         205520 non-null  int64
#  17  soundLevel  205520 non-null  float64
# ...

# %% [markdown]
# ### **Finding the null values in the Dataset**

# %%
# detect null values
df.isnull()
# Out:
#           _id    orX    orY    orZ     rX     rY     rZ   accX   accY   accZ  \
# 0       False  False  False  False  False  False  False  False  False  False
# 1       False  False  False  False  False  False  False  False  False  False
# 2       False  False  False  False  False  False  False  False  False  False
# 3       False  False  False  False  False  False  False  False  False  False
# 4       False  False  False  False  False  False  False  False  False  False
# ...       ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 205515  False  False  False  False  False  False  False  False  False  False
# 205516  False  False  False  False  False  False  False  False  False  False
# 205517  False  False  False  False  False  False  False  False  False  False
# 205518  False  False  False  False  False  False  False  False  False  False
# 205519  False  False  False  False  False  False  False  False  False  False
#
# ...

# %%
#count missing values in each row and column
df.isnull().sum()
# Out:
# _id           0
# orX           0
# orY           0
# orZ           0
# rX            0
# rY            0
# rZ            0
# accX          0
# accY          0
# accZ          0
# gX            0
# gY            0
# gZ            0
# mX            0
# mY            0
# mZ            0
# lux           0
# soundLevel    0
# activity      0
# dtype: int64

# %%
#Heatmap for null values 
sns.heatmap(df.isnull(),cmap = 'magma',cbar = False);

# %% [markdown]
# *   **No null values** are present in the data

# %% [markdown]
# ### **Selecting necessary features from Attributes**

# %%
#Printing out the attributes
col = list(df.columns)
required_features = []
other_features = []
for i in col:
    if ((i != "lux") and (i != "soundLevel")):
        required_features.append(i)
    else:
        other_features.append(i)

print('Required Features :',*required_features)
print('Other Features :',*other_features)
# Out:
# Required Features : _id orX orY orZ rX rY rZ accX accY accZ gX gY gZ mX mY mZ activity
# Other Features : lux soundLevel

# %% [markdown]
# *   Since light and sound sensor are very less relevant for determining the activity of the subject, it is better to not consider the two attributes: **lux** and **soundLevel** for activity context recognition.

# %%
df1 = df.drop(['lux', 'soundLevel'], axis=1)
display(df1)
# Out:
#            _id  orX  orY  orZ    rX    rY    rZ  accX  accY  accZ    gX    gY  \
# 0            1  125  -17    2  0.07 -0.13 -0.88 -0.04  2.68  8.66 -0.04  2.68
# 1            2  126  -17    2  0.07 -0.13 -0.88 -0.04  2.68  8.66 -0.05  2.68
# 2            3  127  -17    2  0.07 -0.13 -0.88  0.15  2.68  8.66 -0.06  2.68
# 3            4  127  -17    2  0.07 -0.13 -0.88  0.15  2.68  8.66 -0.06  2.68
# 4            5  127  -17    2  0.07 -0.13 -0.88  0.15  2.68  8.66 -0.05  2.68
# ...        ...  ...  ...  ...   ...   ...   ...   ...   ...   ...   ...   ...
# 205515  205516  286    6   -2 -0.07 -0.04  0.62 -0.38 -0.80 10.61 -0.19 -1.69
# 205516  205517  286    6   -2 -0.07 -0.04  0.62 -0.38 -0.80 10.61 -0.19 -1.69
# 205517  205518  286    6   -2 -0.07 -0.04  0.62 -0.38 -0.80 10.61 -0.19 -1.69
# 205518  205519  288    4   -2 -0.07 -0.04  0.62 -0.38 -1.15 10.61 -0.20 -1.62
# 205519  205520  288    4   -2 -0.07 -0.04  0.62 -0.38 -1.15 10.61 -0.20 -1.62
#
# ...

# %% [markdown]
# ### **Descriptive Statistics Analysis**

# %%
#Taking attributes for descriptive statistics analysis
df2 = df1[['orX', 'orY', 'orZ', 'rX', 'rY', 'rZ', 'accX', 'accY', 'accZ','gX', 'gY', 'gZ', 'mX', 'mY', 'mZ']].copy()
display(df2)
# Out:
#         orX  orY  orZ    rX    rY    rZ  accX  accY  accZ    gX    gY    gZ  \
# 0       125  -17    2  0.07 -0.13 -0.88 -0.04  2.68  8.66 -0.04  2.68  8.64
# 1       126  -17    2  0.07 -0.13 -0.88 -0.04  2.68  8.66 -0.05  2.68  8.65
# 2       127  -17    2  0.07 -0.13 -0.88  0.15  2.68  8.66 -0.06  2.68  8.65
# 3       127  -17    2  0.07 -0.13 -0.88  0.15  2.68  8.66 -0.06  2.68  8.65
# 4       127  -17    2  0.07 -0.13 -0.88  0.15  2.68  8.66 -0.05  2.68  8.65
# ...     ...  ...  ...   ...   ...   ...   ...   ...   ...   ...   ...   ...
# 205515  286    6   -2 -0.07 -0.04  0.62 -0.38 -0.80 10.61 -0.19 -1.69 10.56
# 205516  286    6   -2 -0.07 -0.04  0.62 -0.38 -0.80 10.61 -0.19 -1.69 10.56
# 205517  286    6   -2 -0.07 -0.04  0.62 -0.38 -0.80 10.61 -0.19 -1.69 10.56
# 205518  288    4   -2 -0.07 -0.04  0.62 -0.38 -1.15 10.61 -0.20 -1.62 10.48
# 205519  288    4   -2 -0.07 -0.04  0.62 -0.38 -1.15 10.61 -0.20 -1.62 10.48
#
#            mX     mY     mZ
# ...

# %% [markdown]
# > **Finding the following for Descriptive Statistical Analysis:**
#
#
# * Mean
# * Median
# * Standard Deviation
# * Variance
# * Minimum
# * Maximum
# * Skewness
# * Kurtosis

# %%
#Mean
df2.mean()
# Out:
# orX    189.46
# orY      2.73
# orZ      0.41
# rX      -0.02
# rY      -0.01
# rZ       0.04
# accX     0.10
# accY    -0.97
# accZ     9.64
# gX       0.10
# gY      -0.98
# gZ       9.65
# mX       0.55
# mY      -9.64
# mZ     -29.45
# dtype: float64

# %%
#Median
df2.median()
# Out:
# orX    186.00
# orY      6.00
# orZ     -1.00
# rX      -0.03
# rY      -0.01
# rZ       0.49
# accX     0.08
# accY    -1.07
# accZ    10.38
# gX       0.08
# gY      -1.03
# gZ      10.33
# mX       5.60
# mY      -7.60
# mZ     -32.40
# dtype: float64

# %%
#Standard Deviation
df2.std()
# Out:
# orX    80.36
# orY    22.45
# orZ    12.44
# rX      0.15
# rY      0.11
# rZ      0.79
# accX    1.95
# accY    2.48
# accZ    2.64
# gX      1.82
# gY      2.34
# gZ      2.11
# mX     20.81
# mY     20.34
# mZ     17.34
# dtype: float64

# %%
#Variance
df2.var()
# Out:
# orX    6457.71
# orY     503.83
# orZ     154.71
# rX        0.02
# rY        0.01
# rZ        0.63
# accX      3.79
# accY      6.17
# accZ      6.96
# gX        3.31
# gY        5.45
# gZ        4.44
# mX      432.96
# mY      413.89
# mZ      300.68
# dtype: float64

# %%
#Minimum
df2.min()
# Out:
# orX       0.00
# orY    -178.00
# orZ     -86.00
# rX       -0.71
# rY       -0.56
# rZ       -1.00
# accX    -19.54
# accY    -14.48
# accZ     -5.98
# gX      -13.66
# gY       -7.99
# gZ       -3.83
# mX     -139.20
# mY      -70.00
# mZ     -107.20
# dtype: float64

# %%
#Maximum
df2.max()
# Out:
# orX    359.00
# orY    169.00
# orZ     88.00
# rX       0.80
# rY       0.72
# rZ       1.00
# accX    15.86
# accY    19.57
# accZ    19.57
# gX      13.66
# gY       9.90
# gZ      14.49
# mX      78.80
# mY     158.40
# mZ      77.20
# dtype: float64

# %%
#Skewness
df2.skew()
# Out:
# orX    -0.25
# orY    -3.34
# orZ     2.16
# rX      2.29
# rY      0.44
# rZ     -0.16
# accX    1.66
# accY    0.65
# accZ   -1.54
# gX      2.22
# gY      0.70
# gZ     -3.62
# mX     -0.59
# mY      0.49
# mZ      0.29
# dtype: float64

# %% [markdown]
# *   If the skewness is between -0.5 & 0.5, the data are nearly symmetrical.
# *   If the skewness is between -1 & -0.5 (negative skewed) or between 0.5 & 1(positive skewed), the data are slightly skewed.
# *  If the skewness is lower than -1 (negative skewed) or greater than 1 (positive skewed), the data are extremely skewed.

# %%
#Kurtosis
df2.kurtosis()
# Out:
# orX    -0.72
# orY    18.42
# orZ    14.56
# rX     11.35
# rY      4.26
# rZ     -1.73
# accX   11.11
# accY    0.26
# accZ    5.60
# gX     13.03
# gY      0.46
# gZ     14.34
# mX      1.02
# mY      2.73
# mZ      0.38
# dtype: float64

# %% [markdown]
# ### **Distribution and Visualisation of Target Variable - Activity**

# %%
# Plot the value_counts with a bar graph
ax = df.activity.value_counts().plot(kind="bar")
plt.title('User Activity');

ax.set_xlabel("ACTIVITY")
ax.set_ylabel("COUNT")
for rect in ax.patches:
    y_value = rect.get_height() 
    x_value = rect.get_x() + rect.get_width() / 2
    space = 1
    label = "{:.0f}".format(y_value)
    ax.annotate(label, (x_value, y_value), xytext=(0, space), textcoords="offset points", ha='center', va='bottom')
plt.show()

# %% [markdown]
# ##### **2) Data Standardisation**

# %%
X = df2
display(X.head())
# Out:
#    orX  orY  orZ   rX    rY    rZ  accX  accY  accZ    gX   gY   gZ     mX  \
# 0  125  -17    2 0.07 -0.13 -0.88 -0.04  2.68  8.66 -0.04 2.68 8.64 -31.20
# 1  126  -17    2 0.07 -0.13 -0.88 -0.04  2.68  8.66 -0.05 2.68 8.65 -31.20
# 2  127  -17    2 0.07 -0.13 -0.88  0.15  2.68  8.66 -0.06 2.68 8.65 -31.20
# 3  127  -17    2 0.07 -0.13 -0.88  0.15  2.68  8.66 -0.06 2.68 8.65 -31.20
# 4  127  -17    2 0.07 -0.13 -0.88  0.15  2.68  8.66 -0.05 2.68 8.65 -31.20
#
#       mY     mZ
# 0 -35.60 -37.60
# 1 -36.00 -37.20
# 2 -36.00 -37.20
# 3 -36.00 -37.20
# 4 -35.60 -36.80

# %%
y = df.iloc[:,-1]
y.unique()
# Out:
# array(['Sitting', 'ClimbingDownStairs', 'Walking', 'Standing',
#        'ClimbingUpStairs', 'Jogging', 'Lying', 'Running', 'Driving',
#        'MountainAscending', 'MountainDescending', 'DescendingStairs',
#        'AscendingStairs'], dtype=object)

# %%
#Standardising the dataset
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler().fit(X)
rescaledX = scaler.transform(X)
X = pd.DataFrame(rescaledX, columns=X.columns)
X.head()
# Out:
#     orX   orY  orZ   rX    rY    rZ  accX  accY  accZ    gX   gY    gZ    mX  \
# 0 -0.80 -0.88 0.13 0.59 -1.06 -1.16 -0.07  1.47 -0.37 -0.08 1.56 -0.48 -1.53
# 1 -0.79 -0.88 0.13 0.60 -1.06 -1.16 -0.07  1.47 -0.37 -0.09 1.57 -0.48 -1.53
# 2 -0.78 -0.88 0.13 0.60 -1.06 -1.16  0.03  1.47 -0.37 -0.09 1.57 -0.47 -1.53
# 3 -0.78 -0.88 0.13 0.60 -1.06 -1.16  0.03  1.47 -0.37 -0.09 1.57 -0.47 -1.53
# 4 -0.78 -0.88 0.13 0.59 -1.06 -1.16  0.03  1.47 -0.37 -0.08 1.57 -0.47 -1.53
#
#      mY    mZ
# 0 -1.28 -0.47
# 1 -1.30 -0.45
# 2 -1.30 -0.45
# 3 -1.30 -0.45
# 4 -1.28 -0.42

# %%
display(X.shape)
# Out:
# (205520, 15)

# %% [markdown]
# ##### **3) SMOTE**

# %%
#Applying SMOTE Technique
from imblearn.over_sampling import SMOTE
smote = SMOTE(random_state = 14)
X_smote, y_smote = smote.fit_resample(X, y)

# %%
# Plot the value_counts with a bar graph
ax = y_smote.value_counts().plot(kind="bar")
plt.title('User Activity');

ax.set_xlabel("ACTIVITY")
ax.set_ylabel("COUNT")
for rect in ax.patches:
    y_value = rect.get_height()
    x_value = rect.get_x() + rect.get_width() / 2
plt.show()

# %%
y_smote = y_smote.astype('category').cat.codes
y_smote.unique()
# Out:
# array([10,  1, 12, 11,  2,  5,  6,  9,  4,  7,  8,  3,  0], dtype=int8)

# %%
datasetDf = X_smote
datasetDf['category'] = y_smote
datasetDf.head()
# Out:
#     orX   orY  orZ   rX    rY    rZ  accX  accY  accZ    gX   gY    gZ    mX  \
# 0 -0.80 -0.88 0.13 0.59 -1.06 -1.16 -0.07  1.47 -0.37 -0.08 1.56 -0.48 -1.53
# 1 -0.79 -0.88 0.13 0.60 -1.06 -1.16 -0.07  1.47 -0.37 -0.09 1.57 -0.48 -1.53
# 2 -0.78 -0.88 0.13 0.60 -1.06 -1.16  0.03  1.47 -0.37 -0.09 1.57 -0.47 -1.53
# 3 -0.78 -0.88 0.13 0.60 -1.06 -1.16  0.03  1.47 -0.37 -0.09 1.57 -0.47 -1.53
# 4 -0.78 -0.88 0.13 0.59 -1.06 -1.16  0.03  1.47 -0.37 -0.08 1.57 -0.47 -1.53
#
#      mY    mZ  category
# 0 -1.28 -0.47        10
# 1 -1.30 -0.45        10
# 2 -1.30 -0.45        10
# 3 -1.30 -0.45        10
# 4 -1.28 -0.42        10

# %%
display(datasetDf.shape)
# Out:
# (984529, 16)

# %%
#Saving it as new csv file
datasetDf.to_csv('standardizedHACR.csv',index=False)
